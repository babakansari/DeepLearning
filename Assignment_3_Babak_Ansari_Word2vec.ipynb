# %% [markdown]
# <a href="https://colab.research.google.com/github/babakansari/DeepLearning/blob/master/Assignment_3_Babak_Ansari_Word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import collections
import hashlib
import math
import os
import random
import sys
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector

data_index = 0
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# Give a folder path as an argument with '--log_dir' to save
# TensorBoard summaries. Default is a log folder in current directory.
current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
flags, unused_flags = parser.parse_known_args()
#word2vec_basic(flags.log_dir)

log_dir = flags.log_dir

def _hash_file(fpath):
  hasher = hashlib.sha256()
  with open(fpath, 'rb') as fpath_file:
    for chunk in iter(lambda: fpath_file.read(65535), b''):
      hasher.update(chunk)
  return hasher.hexdigest()

# %%
"""Example of building, training and visualizing a word2vec model."""
# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(log_dir):
  os.makedirs(log_dir)

# Step 1: Download the data.
# Note: Source website does not support HTTPS right now.
url = 'http://mattmahoney.net/dc/'

# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes, sha256=None):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                    local_filename)
  statinfo = os.stat(local_filename)

  if sha256 and _hash_file(local_filename) != sha256:
    raise Exception('Failed to verify ' + local_filename + ' due to hash '
                    'mismatch. Can you get to it with a browser?')

  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename

filename = maybe_download(
    'text8.zip',
    31344016,
    sha256='a6640522afe85d1963ad56c05b0ede0a0c000dddc9671758a6cc09b7a38e5232')

# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = {word: index for index, (word, _) in enumerate(count)}
  data = []
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - map of codes(integers) to words(strings)
data, count, unused_dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit
# the validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal([vocabulary_size, embedding_size],
                              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss and why choosing NCE over tf.nn.sampled_softmax_loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  #   http://papers.nips.cc/paper/5165-learning-word-embeddings-efficiently-with-noise-contrastive-estimation.pdf
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all
  # embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()

# Step 5: Begin training.
num_steps = 100001
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
with tf.compat.v1.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned
    # "summary" variable. Feed metadata variable to session for visualizing
    # the graph in TensorBoard.
    _, summary, loss_val = session.run([optimizer, merged, loss],
                                        feed_dict=feed_dict,
                                        run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000
      # batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word

        print(
            log_str,
            ', '.join([reverse_dictionary[nearest[k]] for k in range(top_k)]))
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in
  # TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()

# Step 6: Visualize the embeddings.

# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(
        label,
        xy=(x, y),
        xytext=(5, 2),
        textcoords='offset points',
        ha='right',
        va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(
      perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(),
                                                      'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# Initialized
# Average loss at step  0 :  313.4454345703125
# Nearest to b: maidstone, filmed, aground, rivera, exemplifies, inexplicably, copying, wounding
# Nearest to also: wtc, frets, apokryphen, renegade, thule, systematized, hoped, limassol
# Nearest to time: correlations, diamagnets, perceiving, schoolchildren, human, beginning, shell, often
# Nearest to three: goalscorer, neurologists, subfields, reductionism, denomination, gear, eustace, mongolians
# Nearest to one: hecuba, aeolus, hospital, computed, lopez, bridges, definitively, chorales
# Nearest to these: mandragora, julien, stitch, azhar, borges, rarest, https, indented
# Nearest to for: ona, cowdery, thence, raiding, lagos, caledonians, religiously, murat
# Nearest to if: solvable, cycled, reunification, aquinas, gib, implication, irregulars, categorised
# Nearest to by: methodical, cleanup, lada, griffiths, spine, norma, yale, froze
# Nearest to seven: romanus, plot, inmates, immortalised, embroidered, complains, moller, trinitarians
# Nearest to which: monika, ivy, advert, drug, nage, musically, scandinavians, buff
# Nearest to in: approx, saeed, landmass, monographs, aisha, sportsman, trumpeter, steadfast
# Nearest to years: confirms, metamorphic, readiness, willed, printer, torres, barbary, christos
# Nearest to on: shrapnel, perceive, milligan, mango, refered, topologically, diphtheria, teas
# Nearest to up: minesweeper, motivations, likeness, assets, ebb, icmp, metronome, baines
# Nearest to such: xs, moreover, mango, beni, billions, paragliding, conceal, wwii
# Average loss at step  2000 :  113.26586250782013
# Average loss at step  4000 :  52.81130021548271
# Average loss at step  6000 :  32.8639257876873
# Average loss at step  8000 :  23.598574875712394
# Average loss at step  10000 :  18.019535555124282
# Nearest to b: filmed, butane, nine, caused, coke, fins, zero, expert
# Nearest to also: referred, substantially, that, ranking, zar, UNK, was, renegade
# Nearest to time: beginning, human, shell, sense, original, sovereign, bay, trail
# Nearest to three: one, zero, gb, six, nine, eight, hyacinthus, bckgr
# Nearest to one: zero, nine, gb, two, six, jpg, mathbf, three
# Nearest to these: collection, conservative, var, rarest, material, hitting, directory, telephones
# Nearest to for: of, and, in, to, spirits, from, argues, during
# Nearest to if: aquinas, batsman, engines, commands, markets, truth, ada, budget
# Nearest to by: in, and, was, of, UNK, streets, implications, four
# Nearest to seven: zero, nine, five, six, archie, eight, reports, coke
# Nearest to which: drug, and, that, archie, ivy, this, i, nage
# Nearest to in: and, of, on, by, to, morel, nine, for
# Nearest to years: influences, exploits, late, district, civil, basins, heating, limestone
# Nearest to on: in, frequency, geometric, evolution, commissioned, from, for, of
# Nearest to up: motivations, stock, tracks, likeness, reference, prix, gland, necessarily
# Nearest to such: moreover, combined, galt, vs, broad, soldiers, conceal, hooper
# Average loss at step  12000 :  14.112193033218384
# Average loss at step  14000 :  11.806929526329041
# Average loss at step  16000 :  9.885096811413765
# Average loss at step  18000 :  8.474055810332299
# Average loss at step  20000 :  8.327112493753432
# Nearest to b: d, and, ephesians, amazonas, filmed, holocaust, english, shirkuh
# Nearest to also: that, UNK, referred, substantially, genital, operatorname, it, been
# Nearest to time: beginning, shell, circ, human, original, sense, perceiving, sovereign
# Nearest to three: zero, eight, nine, six, five, two, four, one
# Nearest to one: two, six, dasyprocta, nine, five, eight, three, circ
# Nearest to these: the, some, indented, which, collection, remembering, material, hitting
# Nearest to for: and, in, of, to, from, with, as, by
# Nearest to if: dasyprocta, gernsback, batsman, commands, aquinas, operatorname, injuring, engines
# Nearest to by: was, in, is, from, and, for, with, as
# Nearest to seven: nine, eight, five, zero, six, four, dasyprocta, three
# Nearest to which: and, that, this, drug, ivy, archie, dasyprocta, these
# Nearest to in: and, of, for, on, from, agouti, dasyprocta, nine
# Nearest to years: influences, exploits, confirms, printer, dasyprocta, district, nutrition, two
# Nearest to on: in, mango, and, from, for, commissioned, circ, during
# Nearest to up: motivations, stock, likeness, tracks, prix, leroy, geostationary, assets
# Nearest to such: mango, moreover, hooper, well, combined, cation, dasyprocta, originates
# Average loss at step  22000 :  7.127627467870712
# Average loss at step  24000 :  6.846848199009895
# Average loss at step  26000 :  6.799524988174438
# Average loss at step  28000 :  6.355395713686943
# Average loss at step  30000 :  6.004783717513084
# Nearest to b: d, and, ephesians, english, amazonas, filmed, holocaust, maidstone
# Nearest to also: abet, that, it, which, agouti, substantially, operatorname, who
# Nearest to time: beginning, shell, circ, human, perceiving, original, sovereign, intonation
# Nearest to three: eight, six, four, five, two, seven, nine, zero
# Nearest to one: two, four, circ, eight, six, agouti, three, dasyprocta
# Nearest to these: some, which, hitting, indented, moran, material, remembering, var
# Nearest to for: in, and, with, of, to, by, circ, from
# Nearest to if: gib, amalthea, gernsback, dasyprocta, batsman, acadia, is, commands
# Nearest to by: in, from, was, with, for, is, six, and
# Nearest to seven: eight, nine, six, five, four, zero, three, dasyprocta
# Nearest to which: that, this, and, it, these, ivy, but, abakan
# Nearest to in: and, on, at, for, agouti, from, by, nine
# Nearest to years: influences, confirms, metamorphic, printer, exploits, two, peripheral, nutrition
# Nearest to on: in, from, mango, for, during, circ, by, upon
# Nearest to up: motivations, difranco, baines, assets, stock, likeness, tracks, abet
# Nearest to such: well, mango, moreover, hooper, dasyprocta, cation, sterilized, miscarriage
# Average loss at step  32000 :  5.962980048894882
# Average loss at step  34000 :  5.689947733998299
# Average loss at step  36000 :  5.761796559333801
# Average loss at step  38000 :  5.523558344721794
# Average loss at step  40000 :  5.2634672994613645
# Nearest to b: d, amazonas, zero, ephesians, cin, filmed, english, dasyprocta
# Nearest to also: abet, which, that, it, agouti, operatorname, not, who
# Nearest to time: beginning, circ, shell, human, perceiving, bake, intonation, amalthea
# Nearest to three: four, six, five, eight, seven, two, zero, nine
# Nearest to one: two, six, four, eight, three, five, seven, zero
# Nearest to these: some, which, moran, many, hitting, indented, material, stitch
# Nearest to for: of, and, with, in, zero, circ, abet, under
# Nearest to if: when, gib, amalthea, gernsback, dasyprocta, batsman, but, commands
# Nearest to by: was, be, is, with, in, from, for, six
# Nearest to seven: eight, six, five, four, nine, three, zero, one
# Nearest to which: that, this, it, but, also, and, these, ivy
# Nearest to in: on, albury, from, at, and, agouti, of, dasyprocta
# Nearest to years: influences, six, confirms, metamorphic, printer, three, exploits, four
# Nearest to on: in, from, during, upon, mango, for, circ, abet
# Nearest to up: senex, motivations, baines, difranco, metronome, assets, kournikova, likeness
# Nearest to such: well, hooper, moreover, mango, miscarriage, dasyprocta, cremated, known
# Average loss at step  42000 :  5.366339663743973
# Average loss at step  44000 :  5.24549997138977
# Average loss at step  46000 :  5.218891166567802
# Average loss at step  48000 :  5.230539151906967
# Average loss at step  50000 :  4.992105675816536
# Nearest to b: d, amazonas, and, dasyprocta, six, kapoor, abet, UNK
# Nearest to also: which, abet, it, not, agouti, that, often, then
# Nearest to time: kapoor, circ, bake, perceiving, beginning, shell, intonation, fuzes
# Nearest to three: four, six, five, seven, two, eight, one, kapoor
# Nearest to one: two, six, seven, four, five, three, eight, kapoor
# Nearest to these: some, which, many, moran, all, hitting, teams, two
# Nearest to for: in, mukherjee, and, circ, of, abet, to, albury
# Nearest to if: when, amalthea, gib, dasyprocta, but, mukherjee, gernsback, is
# Nearest to by: was, be, with, is, for, as, in, from
# Nearest to seven: eight, six, five, three, four, nine, zero, one
# Nearest to which: that, this, and, it, also, these, but, one
# Nearest to in: on, albury, at, for, agouti, from, during, and
# Nearest to years: confirms, metamorphic, influences, four, printer, three, exploits, year
# Nearest to on: in, during, from, circ, upon, abet, at, mango
# Nearest to up: baines, senex, difranco, motivations, metronome, kournikova, assets, failure
# Nearest to such: well, these, known, moreover, hooper, gertrude, cremated, miscarriage
# Average loss at step  52000 :  5.056017565131188
# Average loss at step  54000 :  5.166108076453209
# Average loss at step  56000 :  5.040691194534301
# Average loss at step  58000 :  5.056973034143448
# Average loss at step  60000 :  4.951597711086273
# Nearest to b: d, leak, amazonas, wheat, aground, wounding, j, UNK
# Nearest to also: abet, which, agouti, it, that, then, operatorname, not
# Nearest to time: kapoor, sense, circ, pulau, bake, perceiving, fuzes, amalthea
# Nearest to three: four, five, six, two, eight, seven, one, nine
# Nearest to one: two, six, four, three, five, eight, seven, circ
# Nearest to these: some, many, moran, all, which, such, two, teams
# Nearest to for: in, of, mukherjee, and, to, circ, or, as
# Nearest to if: when, but, is, amalthea, gib, dasyprocta, for, mukherjee
# Nearest to by: was, be, with, under, ursus, from, six, swear
# Nearest to seven: eight, six, nine, five, zero, three, four, kapoor
# Nearest to which: that, this, it, but, also, however, and, one
# Nearest to in: on, at, albury, during, and, from, agouti, between
# Nearest to years: metamorphic, influences, confirms, six, year, weighed, four, exploits
# Nearest to on: in, upon, during, from, at, mango, circ, abet
# Nearest to up: baines, difranco, senex, motivations, metronome, kournikova, michelob, failure
# Nearest to such: well, these, known, cremated, moreover, hooper, miscarriage, dasyprocta
# Average loss at step  62000 :  5.010028928637505
# Average loss at step  64000 :  4.843171701848507
# Average loss at step  66000 :  4.602600755572319
# Average loss at step  68000 :  4.969477921843529
# Average loss at step  70000 :  4.9132124440670015
# Nearest to b: d, UNK, amazonas, j, dasyprocta, leak, wounding, upanija
# Nearest to also: abet, which, often, cebus, agouti, not, it, then
# Nearest to time: sense, microcebus, kapoor, bake, pulau, circ, fuzes, perceiving
# Nearest to three: six, four, five, eight, two, seven, nine, microcebus
# Nearest to one: six, two, four, five, seven, eight, kapoor, three
# Nearest to these: some, many, which, all, moran, such, teams, hitting
# Nearest to for: of, mukherjee, in, and, circ, abet, despite, upanija
# Nearest to if: when, amalthea, gib, but, dasyprocta, for, is, gernsback
# Nearest to by: be, was, with, thaler, ursus, swear, under, as
# Nearest to seven: eight, six, five, nine, four, three, zero, microcebus
# Nearest to which: that, this, but, it, also, however, these, what
# Nearest to in: albury, agouti, at, during, on, and, until, dasyprocta
# Nearest to years: metamorphic, confirms, year, influences, months, six, kapoor, four
# Nearest to on: upon, in, mango, during, circ, from, at, abet
# Nearest to up: baines, difranco, senex, motivations, back, metronome, him, asperger
# Nearest to such: well, these, callithrix, known, cremated, miscarriage, some, hooper
# Average loss at step  72000 :  4.754396643280983
# Average loss at step  74000 :  4.805683469295501
# Average loss at step  76000 :  4.7215177003145214
# Average loss at step  78000 :  4.80439508214593
# Average loss at step  80000 :  4.798545014083386
# Nearest to b: d, UNK, amazonas, j, wounding, dasyprocta, leak, aground
# Nearest to also: often, which, abet, cebus, it, agouti, now, operatorname
# Nearest to time: microcebus, sense, kapoor, pulau, circ, iit, bake, fuzes
# Nearest to three: six, four, five, two, seven, eight, microcebus, nine
# Nearest to one: six, two, seven, five, four, eight, three, ursus
# Nearest to these: some, many, all, such, which, moran, those, teams
# Nearest to for: mukherjee, circ, of, despite, to, upanija, in, abet
# Nearest to if: when, gib, amalthea, fachhochschule, dasyprocta, ascalon, where, but
# Nearest to by: was, be, in, with, under, thaler, as, ursus
# Nearest to seven: six, eight, five, four, nine, three, zero, microcebus
# Nearest to which: that, this, it, but, also, however, there, these
# Nearest to in: during, albury, agouti, at, and, ursus, cebus, from
# Nearest to years: metamorphic, months, year, confirms, influences, weighed, kapoor, six
# Nearest to on: upon, in, during, circ, at, mango, ursus, through
# Nearest to up: baines, difranco, him, senex, motivations, back, metronome, asperger
# Nearest to such: well, these, known, callithrix, some, cremated, hooper, miscarriage
# Average loss at step  82000 :  4.781636931300163
# Average loss at step  84000 :  4.749579225182533
# Average loss at step  86000 :  4.759484204411507
# Average loss at step  88000 :  4.747300825595856
# Average loss at step  90000 :  4.734651310801506
# Nearest to b: d, UNK, j, leak, wounding, amazonas, aground, c
# Nearest to also: often, which, abet, cebus, it, now, not, vary
# Nearest to time: sense, microcebus, kapoor, pulau, fuzes, bake, circ, balder
# Nearest to three: five, six, four, two, seven, eight, one, nine
# Nearest to one: two, four, three, seven, six, five, eight, crb
# Nearest to these: some, many, such, all, which, moran, those, are
# Nearest to for: mukherjee, despite, in, and, circ, with, abet, to
# Nearest to if: when, where, amalthea, fachhochschule, ascalon, but, though, gib
# Nearest to by: was, be, as, in, with, thaler, from, ursus
# Nearest to seven: eight, five, six, four, nine, three, zero, microcebus
# Nearest to which: that, this, but, it, however, also, these, what
# Nearest to in: during, on, albury, at, agouti, and, ursus, within
# Nearest to years: months, year, metamorphic, weighed, influences, confirms, two, four
# Nearest to on: in, upon, dreidel, during, through, circ, from, at
# Nearest to up: baines, him, back, difranco, them, motivations, senex, metronome
# Nearest to such: well, these, callithrix, known, some, cremated, many, iit
# Average loss at step  92000 :  4.675748152852059
# Average loss at step  94000 :  4.72203414440155
# Average loss at step  96000 :  4.691232679128647
# Average loss at step  98000 :  4.602009618639946
# Average loss at step  100000 :  4.689375480055809
# Nearest to b: d, j, amazonas, leak, UNK, dasyprocta, globemaster, hmos
# Nearest to also: often, which, abet, cebus, sometimes, still, now, agouti
# Nearest to time: sense, microcebus, kapoor, bristles, circ, pulau, balder, abet
# Nearest to three: four, five, six, seven, two, eight, nine, microcebus
# Nearest to one: seven, two, five, eight, six, four, three, crb
# Nearest to these: some, many, such, all, which, moran, their, those
# Nearest to for: despite, mukherjee, circ, upanija, dreidel, albury, of, demanded
# Nearest to if: when, is, where, though, since, amalthea, but, ascalon
# Nearest to by: be, was, as, thaler, ursus, with, UNK, under
# Nearest to seven: six, eight, five, four, nine, three, zero, microcebus
# Nearest to which: that, this, but, however, also, it, what, these
# Nearest to in: during, at, on, agouti, albury, until, from, since
# Nearest to years: months, year, metamorphic, four, three, influences, weighed, confirms
# Nearest to on: upon, in, during, through, dreidel, at, from, circ
# Nearest to up: back, him, baines, difranco, them, out, down, senex
# Nearest to such: these, well, known, callithrix, some, many, dmd, iit
