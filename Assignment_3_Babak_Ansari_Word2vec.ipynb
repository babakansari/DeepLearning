# %% [markdown]
# <a href="https://colab.research.google.com/github/babakansari/DeepLearning/blob/master/Assignment_3_Babak_Ansari_Word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import collections
import hashlib
import math
import os
import random
import sys
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector

data_index = 0
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# Give a folder path as an argument with '--log_dir' to save
# TensorBoard summaries. Default is a log folder in current directory.
current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
flags, unused_flags = parser.parse_known_args()
#word2vec_basic(flags.log_dir)

log_dir = flags.log_dir

def _hash_file(fpath):
  hasher = hashlib.sha256()
  with open(fpath, 'rb') as fpath_file:
    for chunk in iter(lambda: fpath_file.read(65535), b''):
      hasher.update(chunk)
  return hasher.hexdigest()

# %%
"""Example of building, training and visualizing a word2vec model."""
# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(log_dir):
  os.makedirs(log_dir)

# Step 1: Download the data.
# Note: Source website does not support HTTPS right now.
url = 'http://mattmahoney.net/dc/'

# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes, sha256=None):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                    local_filename)
  statinfo = os.stat(local_filename)

  if sha256 and _hash_file(local_filename) != sha256:
    raise Exception('Failed to verify ' + local_filename + ' due to hash '
                    'mismatch. Can you get to it with a browser?')

  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename

filename = maybe_download(
    'text8.zip',
    31344016,
    sha256='a6640522afe85d1963ad56c05b0ede0a0c000dddc9671758a6cc09b7a38e5232')

# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = {word: index for index, (word, _) in enumerate(count)}
  data = []
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - map of codes(integers) to words(strings)
data, count, unused_dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# 2204 route -> 2 of
# 2204 route -> 2040 principal
# 2 of -> 2204 route
# 2 of -> 1883 transportation
# 1883 transportation -> 2 of
# 1883 transportation -> 14 for
# 14 for -> 290 western
# 14 for -> 1883 transportation

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit
# the validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal([vocabulary_size, embedding_size],
                              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss and why choosing NCE over tf.nn.sampled_softmax_loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  #   http://papers.nips.cc/paper/5165-learning-word-embeddings-efficiently-with-noise-contrastive-estimation.pdf
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all
  # embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()

# Step 5: Begin training.
num_steps = 100001

# %%
with tf.compat.v1.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned
    # "summary" variable. Feed metadata variable to session for visualizing
    # the graph in TensorBoard.
    _, summary, loss_val = session.run([optimizer, merged, loss],
                                        feed_dict=feed_dict,
                                        run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000
      # batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word

        print(
            log_str,
            ', '.join([reverse_dictionary[nearest[k]] for k in range(top_k)]))
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in
  # TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()

# Step 6: Visualize the embeddings.

# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(
        label,
        xy=(x, y),
        xytext=(5, 2),
        textcoords='offset points',
        ha='right',
        va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(
      perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(),
                                                      'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# Initialized
# Average loss at step  0 :  261.15167236328125
# Nearest to history: barr, became, francais, julie, compliance, orser, individuals, imams
# Nearest to if: vives, boils, grouped, surveyed, diaz, painfully, alberoni, enveloping
# Nearest to new: punchline, consonants, acceleration, philosophy, pomerania, tau, westcott, increasing
# Nearest to and: espouse, lar, nouns, bees, aqueducts, pick, ascertain, gingrich
# Nearest to no: weidman, ethelred, force, detachments, farmers, berlusconi, compensatory, haddock
# Nearest to they: hydrates, rarely, girls, purebred, current, formula, cossack, shem
# Nearest to th: nica, spliced, punctuation, furs, chemists, sized, du, abnormalities
# Nearest to eight: interfacing, workers, herod, loire, b, saud, unido, fundamento
# Nearest to i: myrrh, unarmed, ustawa, wrestler, angus, mays, albans, liffey
# Nearest to as: wto, unveiled, tagus, schmitt, articles, ccp, evacuate, debra
# Nearest to first: captors, hat, maximal, yorkshire, shreveport, mckellen, barada, terminus
# Nearest to nine: making, deflate, cauca, biosynthesis, embarrassment, minefields, paraphrase, me
# Nearest to called: trout, aubrey, culprits, lib, fragment, oakenfold, dal, radiation
# Nearest to this: quote, kyrenia, hau, ornaments, zapatistas, dear, cabell, mathfrak
# Nearest to known: obstructing, ushered, hara, warrior, fistula, shoe, spacey, hopkinson
# Nearest to more: loyalties, editorship, visualize, worst, quota, marat, ecclesiology, almoravides
# Average loss at step  2000 :  114.13896103286743
# Average loss at step  4000 :  52.87442372441292
# Average loss at step  6000 :  33.360847209692004
# Average loss at step  8000 :  23.390787054300308
# Average loss at step  10000 :  17.65198058593273
# Nearest to history: became, individuals, curse, francais, dvorak, sphere, prefix, lying
# Nearest to if: rw, injection, township, surveyed, dione, anyone, grouped, perro
# Nearest to new: dagome, increasing, philosophy, consonants, jessica, controversial, dimensions, ecm
# Nearest to and: of, in, the, UNK, by, dvorak, to, one
# Nearest to no: township, parental, force, problems, es, allows, river, taking
# Nearest to they: rarely, barks, outbursts, participation, he, girls, dtmf, township
# Nearest to th: nine, kent, tors, dvorak, zero, appearances, one, five
# Nearest to eight: nine, zero, dvorak, tier, three, six, two, five
# Nearest to i: liffey, repositories, dulcimer, dor, vector, sh, holy, benefits
# Nearest to as: is, wto, with, by, in, and, dative, ph
# Nearest to first: hat, township, photon, delaunay, ask, barada, dvorak, resolvers
# Nearest to nine: eight, zero, dvorak, congregations, township, one, astrology, five
# Nearest to called: trout, album, aubrey, pinscher, radiation, keeper, competitors, oakenfold
# Nearest to this: a, the, goals, pistons, dor, which, hymen, quote
# Nearest to known: foreground, pistons, hara, waters, attacks, pressed, necromancer, edge
# Nearest to more: marat, post, pendulum, rpg, register, editorship, visualize, planets
# Average loss at step  12000 :  14.255496485352516
# Average loss at step  14000 :  11.34611474108696
# Average loss at step  16000 :  9.345998681783676
# Average loss at step  18000 :  8.90614401960373
# Average loss at step  20000 :  8.014718164682389
# Nearest to history: barr, curse, individuals, francais, became, viollet, sousa, gloucester
# Nearest to if: rw, surveyed, injection, huang, anyone, puberty, is, dione
# Nearest to new: jessica, dagome, philosophy, consonants, increasing, controversial, empedocles, mountains
# Nearest to and: or, in, of, dvorak, for, eight, smells, zero
# Nearest to no: smells, township, parental, marconi, haddock, further, force, allows
# Nearest to they: he, rarely, barks, it, girls, participation, outbursts, who
# Nearest to th: five, one, tors, kent, dvorak, punctuation, dune, nine
# Nearest to eight: nine, dvorak, zero, five, three, four, seven, six
# Nearest to i: liffey, repositories, benefits, dor, vector, architects, holy, dulcimer
# Nearest to as: by, and, wto, with, congregations, for, cadet, dative
# Nearest to first: hubs, hat, forests, resolvers, township, visit, ask, in
# Nearest to nine: eight, zero, dvorak, seven, six, smells, congregations, five
# Nearest to called: aubrey, and, album, trout, pinscher, radiation, keeper, oakenfold
# Nearest to this: the, which, a, dear, it, his, hymen, pistons
# Nearest to known: foreground, hara, pistons, waters, ushered, shoe, attacks, costume
# Nearest to more: marat, black, rpg, post, often, narrower, ukrainian, editorship
# Average loss at step  22000 :  7.397930204153061
# Average loss at step  24000 :  6.928040225148201
# Average loss at step  26000 :  6.5944532853364946
# Average loss at step  28000 :  6.183640461921692
# Average loss at step  30000 :  5.929331226825714
# Nearest to history: barr, curse, psych, individuals, francais, sousa, lisp, locally
# Nearest to if: surveyed, rw, huang, irish, injection, essayist, dione, perro
# Nearest to new: jessica, one, dagome, philosophy, empedocles, wp, bafta, neighboring
# Nearest to and: or, in, widehat, quagga, hemionus, sanjo, smells, UNK
# Nearest to no: smells, township, quagga, further, parental, marconi, hemionus, a
# Nearest to they: he, rarely, it, barks, we, who, hemionus, there
# Nearest to th: five, eight, seven, spliced, tors, punctuation, furs, nine
# Nearest to eight: nine, seven, six, five, four, zero, three, dvorak
# Nearest to i: auschwitz, liffey, benefits, dor, vector, repositories, holy, quagga
# Nearest to as: by, congregations, and, wto, hemionus, widehat, with, in
# Nearest to first: hubs, township, hat, dvorak, forests, resolvers, visit, dor
# Nearest to nine: eight, seven, zero, six, five, four, dvorak, three
# Nearest to called: and, aubrey, album, quagga, pinscher, trout, radiation, fragment
# Nearest to this: which, the, it, a, quagga, dear, that, pistons
# Nearest to known: foreground, hara, obstructing, ushered, pistons, waters, simultaneous, jenny
# Nearest to more: marat, rpg, editorship, hemionus, post, mari, brawl, black
# Average loss at step  32000 :  5.815514167070389
# Average loss at step  34000 :  5.637330911278725
# Average loss at step  36000 :  5.680102284669876
# Average loss at step  38000 :  5.5322742755413055
# Average loss at step  40000 :  5.382051753163338
# Nearest to history: barr, curse, locally, psych, UNK, dvorak, francais, individuals
# Nearest to if: surveyed, huang, rw, dione, five, irish, when, perro
# Nearest to new: philosophy, dagome, jessica, wp, bafta, antiquark, westcott, empedocles
# Nearest to and: or, quagga, but, widehat, hemionus, smells, in, sanjo
# Nearest to no: smells, township, further, quagga, and, a, it, unido
# Nearest to they: he, we, it, who, rarely, there, barks, hemionus
# Nearest to th: five, spliced, nica, seven, eight, nine, furs, four
# Nearest to eight: nine, seven, six, five, four, zero, three, dvorak
# Nearest to i: auschwitz, liffey, dor, benefits, repositories, vector, holy, catahoula
# Nearest to as: congregations, hemionus, by, dative, with, for, widehat, quagga
# Nearest to first: hubs, dvorak, township, forests, hat, males, dor, visit
# Nearest to nine: eight, seven, six, five, four, zero, dvorak, three
# Nearest to called: and, aubrey, album, pinscher, quagga, competitors, trout, fragment
# Nearest to this: which, it, the, a, that, quagga, pistons, shift
# Nearest to known: foreground, hara, obstructing, ushered, pistons, jenny, simultaneous, waters
# Nearest to more: quota, berenguer, hemionus, rpg, marat, editorship, mari, black
# Average loss at step  42000 :  5.695656429946423
# Average loss at step  44000 :  5.2813235737085344
# Average loss at step  46000 :  5.2324282160997395
# Average loss at step  48000 :  5.1478601245880125
# Average loss at step  50000 :  5.027959029316902
# Nearest to history: stadtbahn, curse, zut, barr, dvorak, locally, kiang, psych
# Nearest to if: when, surveyed, huang, rw, dione, irish, essayist, injection
# Nearest to new: one, dagome, wp, philosophy, jessica, westcott, isolate, acceded
# Nearest to and: or, widehat, socket, zut, catfish, but, stadtbahn, quagga
# Nearest to no: smells, further, quagga, a, township, it, unido, eight
# Nearest to they: he, we, it, there, who, rarely, you, not
# Nearest to th: five, nica, seven, eight, spliced, one, six, furs
# Nearest to eight: seven, nine, six, five, four, three, zero, catfish
# Nearest to i: auschwitz, zut, dor, loach, hab, vector, liffey, diagnosed
# Nearest to as: glas, congregations, dative, by, hemionus, widehat, is, catfish
# Nearest to first: dvorak, hubs, forests, township, last, dor, catfish, stadtbahn
# Nearest to nine: eight, seven, six, five, zero, four, catfish, dvorak
# Nearest to called: and, aubrey, arctocephalus, album, quagga, fragment, culprits, trout
# Nearest to this: which, it, the, that, quagga, catfish, pistons, striping
# Nearest to known: foreground, hara, obstructing, ushered, annoy, pistons, used, pressed
# Nearest to more: stadtbahn, berenguer, catfish, rpg, quota, black, editorship, hemionus
# Average loss at step  52000 :  4.941261315703392
# Average loss at step  54000 :  5.108281261980534
# Average loss at step  56000 :  5.1301035338640215
# Average loss at step  58000 :  5.0856229436397555
# Average loss at step  60000 :  5.0417468460798265
# Nearest to history: stadtbahn, cholera, gru, curse, dvorak, zut, locally, rotunda
# Nearest to if: when, surveyed, gru, huang, rw, dione, irish, stadtbahn
# Nearest to new: philosophy, dagome, wp, westcott, isolate, jessica, acceded, one
# Nearest to and: or, but, gru, catfish, socket, zut, widehat, gbu
# Nearest to no: smells, further, a, quagga, township, often, catfish, unido
# Nearest to they: he, we, there, it, who, you, rarely, not
# Nearest to th: five, eight, nica, seven, spliced, six, four, one
# Nearest to eight: seven, nine, six, five, four, three, zero, dvorak
# Nearest to i: auschwitz, dor, loach, hab, zut, he, kamen, quagga
# Nearest to as: glas, gru, congregations, hemionus, widehat, when, dative, by
# Nearest to first: last, dvorak, second, forests, hubs, township, catfish, dor
# Nearest to nine: eight, seven, six, five, zero, four, three, dvorak
# Nearest to called: and, gru, arctocephalus, quagga, knuckle, album, aubrey, competitors
# Nearest to this: which, it, the, that, catfish, quagga, pistons, gru
# Nearest to known: foreground, hara, used, obstructing, ushered, pistons, annoy, such
# Nearest to more: stadtbahn, most, berenguer, catfish, cottage, inefficient, editorship, dieppe
# Average loss at step  62000 :  4.99877934885025
# Average loss at step  64000 :  4.886875143170356
# Average loss at step  66000 :  4.7778271749019625
# Average loss at step  68000 :  4.8248615899086
# Average loss at step  70000 :  4.869386838674545
# Nearest to history: stadtbahn, gru, dvorak, cholera, zut, curse, catfish, widehat
# Nearest to if: when, surveyed, gru, huang, dione, is, irish, rw
# Nearest to new: philosophy, wp, dagome, acceded, jessica, westcott, one, isolate
# Nearest to and: or, but, gru, catfish, zut, socket, widehat, smells
# Nearest to no: a, smells, further, quagga, it, often, township, haddock
# Nearest to they: we, he, there, it, who, you, not, rarely
# Nearest to th: five, eight, nine, four, nica, seven, six, spliced
# Nearest to eight: seven, nine, six, five, four, three, zero, two
# Nearest to i: auschwitz, loach, dor, hab, zut, he, pharmacological, quagga
# Nearest to as: glas, gru, when, dative, congregations, hemionus, widely, hz
# Nearest to first: second, last, dvorak, hubs, forests, township, catfish, dor
# Nearest to nine: eight, six, seven, five, zero, four, three, gru
# Nearest to called: and, gru, knuckle, arctocephalus, quagga, album, fragment, competitors
# Nearest to this: which, it, that, the, catfish, one, quagga, pistons
# Nearest to known: foreground, used, hara, such, ushered, pistons, annoy, obstructing
# Nearest to more: most, stadtbahn, very, berenguer, catfish, cottage, inefficient, pendulum
# Average loss at step  72000 :  4.8210383360385896
# Average loss at step  74000 :  4.836050139307976
# Average loss at step  76000 :  4.8324790365695955
# Average loss at step  78000 :  4.764854190826416
# Average loss at step  80000 :  4.785628227949142
# Nearest to history: gru, stadtbahn, dvorak, zut, landsmannschaft, catfish, widehat, balas
# Nearest to if: when, surveyed, gru, huang, is, irish, although, dione
# Nearest to new: philosophy, wp, major, dagome, westcott, jessica, acceded, sanjo
# Nearest to and: or, but, gru, socket, landsmannschaft, catfish, zut, widehat
# Nearest to no: a, murbella, further, smells, any, quagga, haddock, often
# Nearest to they: we, he, there, you, who, it, not, rarely
# Nearest to th: eight, five, six, nine, seven, nica, landsmannschaft, four
# Nearest to eight: seven, nine, six, four, five, three, zero, two
# Nearest to i: auschwitz, you, he, ii, hab, they, loach, pharmacological
# Nearest to as: glas, gru, dative, when, hemionus, congregations, evacuate, widehat
# Nearest to first: second, last, dvorak, forests, electorate, hubs, before, landsmannschaft
# Nearest to nine: eight, seven, six, four, five, zero, three, dvorak
# Nearest to called: and, knuckle, gru, quagga, arctocephalus, album, fragment, aubrey
# Nearest to this: which, it, the, that, catfish, quagga, a, pistons
# Nearest to known: used, foreground, hara, such, ebne, pistons, ushered, annoy
# Nearest to more: most, very, stadtbahn, inefficient, less, cottage, berenguer, mari
# Average loss at step  82000 :  4.733219005703926
